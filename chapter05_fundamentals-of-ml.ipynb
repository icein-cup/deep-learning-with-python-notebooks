# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Fundamentals of machine learning

# %% [markdown]
# ### Generalization: The goal of machine learning

# %% [markdown]
# #### Underfitting and overfitting

# %% [markdown]
# ##### Noisy training data

# %% [markdown]
# ##### Ambiguous features

# %% [markdown]
# ##### Rare features and spurious correlations

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)

# %%
import keras
from keras import layers

def get_model():
    model = keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8673 - loss: 0.4455 - val_accuracy: 0.9193 - val_loss: 0.2717
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9325 - loss: 0.2337 - val_accuracy: 0.9414 - val_loss: 0.2025
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9520 - loss: 0.1612 - val_accuracy: 0.9402 - val_loss: 0.2019
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9657 - loss: 0.1167 - val_accuracy: 0.9497 - val_loss: 0.1645
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9758 - loss: 0.0853 - val_accuracy: 0.9556 - val_loss: 0.1547
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9812 - loss: 0.0637 - val_accuracy: 0.9580 - val_loss: 0.1487
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0440 - val_accuracy: 0.9577 - val_loss: 0.1478
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.0331 - val_accuracy: 0.9630 - val_loss: 0.1309
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9952 - loss: 0.0209 - val_accuracy: 0.9588 - val_loss: 0.1456
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0152 - val_accuracy: 0.9589 - val_loss: 0.1522
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9157 - loss: 0.3017 - val_accuracy: 0.9556 - val_loss: 0.1586
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9626 - loss: 0.1290 - val_accuracy: 0.9653 - val_loss: 0.1201
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9753 - loss: 0.0846 - val_accuracy: 0.9707 - val_loss: 0.0973
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9824 - loss: 0.0605 - val_accuracy: 0.9746 - val_loss: 0.0881
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9881 - loss: 0.0442 - val_accuracy: 0.9758 - val_loss: 0.0833
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9902 - loss: 0.0338 - val_accuracy: 0.9753 - val_loss: 0.0814
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9936 - loss: 0.0242 - val_accuracy: 0.9758 - val_loss: 0.0856
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9957 - loss: 0.0181 - val_accuracy: 0.9772 - val_loss: 0.0790
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0144 - val_accuracy: 0.9777 - val_loss: 0.0787
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9978 - loss: 0.0106 - val_accuracy: 0.9786 - val_loss: 0.0812

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b-",
    label="Validation accuracy with noise channels",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label="Validation accuracy with zeros channels",
)
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### The nature of generalization in deep learning

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images,
    random_train_labels,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1040 - loss: 2.3151 - val_accuracy: 0.0990 - val_loss: 2.3079
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1178 - loss: 2.2990 - val_accuracy: 0.1010 - val_loss: 2.3121
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1248 - loss: 2.2910 - val_accuracy: 0.1037 - val_loss: 2.3164
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1396 - loss: 2.2796 - val_accuracy: 0.1021 - val_loss: 2.3274
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1532 - loss: 2.2632 - val_accuracy: 0.1042 - val_loss: 2.3317
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1652 - loss: 2.2428 - val_accuracy: 0.1008 - val_loss: 2.3468
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1809 - loss: 2.2198 - val_accuracy: 0.1041 - val_loss: 2.3626
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1975 - loss: 2.1937 - val_accuracy: 0.0982 - val_loss: 2.3755
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2109 - loss: 2.1649 - val_accuracy: 0.1013 - val_loss: 2.4008
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2292 - loss: 2.1320 - val_accuracy: 0.1085 - val_loss: 2.4136
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2447 - loss: 2.0984 - val_accuracy: 0.1042 - val_loss: 2.4462
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2627 - loss: 2.0624 - val_accuracy: 0.1029 - val_loss: 2.4555
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2792 - loss: 2.0255 - val_accuracy: 0.1034 - val_loss: 2.5041
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2966 - loss: 1.9886 - val_accuracy: 0.1050 - val_loss: 2.5353
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3121 - loss: 1.9502 - val_accuracy: 0.1030 - val_loss: 2.5475
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3285 - loss: 1.9129 - val_accuracy: 0.1076 - val_loss: 2.5823
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3431 - loss: 1.8730 - val_accuracy: 0.1006 - val_loss: 2.6273
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3581 - loss: 1.8364 - val_accuracy: 0.1007 - val_loss: 2.6551
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3745 - loss: 1.8004 - val_accuracy: 0.0996 - val_loss: 2.6997
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3897 - loss: 1.7612 - val_accuracy: 0.1046 - val_loss: 2.7556
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4037 - loss: 1.7251 - val_accuracy: 0.1023 - val_loss: 2.7809
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4215 - loss: 1.6858 - val_accuracy: 0.1021 - val_loss: 2.8354
# Epoch 23/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4294 - loss: 1.6497 - val_accuracy: 0.1029 - val_loss: 2.8828
# Epoch 24/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.
100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8549 - loss: 0.4616 - val_accuracy: 0.1043 - val_loss: 6.6149
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8574 - loss: 0.4532 - val_accuracy: 0.1021 - val_loss: 6.6846
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8613 - loss: 0.4444 - val_accuracy: 0.1028 - val_loss: 6.7285
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8622 - loss: 0.4370 - val_accuracy: 0.1023 - val_loss: 6.7648
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8654 - loss: 0.4299 - val_accuracy: 0.1027 - val_loss: 6.8303
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8684 - loss: 0.4197 - val_accuracy: 0.1052 - val_loss: 6.8829
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8722 - loss: 0.4117 - val_accuracy: 0.1016 - val_loss: 6.9209
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8735 - loss: 0.4058 - val_accuracy: 0.0981 - val_loss: 6.9806
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8734 - loss: 0.4013 - val_accuracy: 0.1043 - val_loss: 7.0224
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8781 - loss: 0.3918 - val_accuracy: 0.1018 - val_loss: 7.1140
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8813 - loss: 0.3836 - val_accuracy: 0.1026 - val_loss: 7.1490
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8820 - loss: 0.3791 - val_accuracy: 0.1030 - val_loss: 7.1856
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8844 - loss: 0.3710 - val_accuracy: 0.1020 - val_loss: 7.2749
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8871 - loss: 0.3656 - val_accuracy: 0.1018 - val_loss: 7.3183
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8900 - loss: 0.3589 - val_accuracy: 0.1010 - val_loss: 7.3779

# %% [markdown]
# ##### The manifold hypothesis

# %% [markdown]
# ##### Interpolation as a source of generalization

# %% [markdown]
# ##### Why deep learning works

# %% [markdown]
# ##### Training data is paramount

# %% [markdown]
# ### Evaluating machine-learning models

# %% [markdown]
# #### Training, validation, and test sets

# %% [markdown]
# ##### Simple hold-out validation

# %% [markdown]
# ##### K-fold validation

# %% [markdown]
# ##### Iterated K-fold validation with shuffling

# %% [markdown]
# #### Beating a common-sense baseline

# %% [markdown]
# #### Things to keep in mind about model evaluation

# %% [markdown]
# ### Improving model fit

# %% [markdown]
# #### Tuning key gradient descent parameters

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1.0),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0998 - loss: 14.4757 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1000 - loss: 14.5056 - val_accuracy: 0.0956 - val_loss: 14.5775

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-2),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9103 - loss: 0.4185 - val_accuracy: 0.9489 - val_loss: 0.1876
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9654 - loss: 0.1237 - val_accuracy: 0.9570 - val_loss: 0.1926
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9744 - loss: 0.1009 - val_accuracy: 0.9637 - val_loss: 0.1582
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9796 - loss: 0.0824 - val_accuracy: 0.9698 - val_loss: 0.1533
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9821 - loss: 0.0719 - val_accuracy: 0.9685 - val_loss: 0.1819
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9850 - loss: 0.0638 - val_accuracy: 0.9731 - val_loss: 0.1583
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9865 - loss: 0.0582 - val_accuracy: 0.9682 - val_loss: 0.2145
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9884 - loss: 0.0517 - val_accuracy: 0.9705 - val_loss: 0.2201
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9901 - loss: 0.0471 - val_accuracy: 0.9738 - val_loss: 0.1805
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9907 - loss: 0.0419 - val_accuracy: 0.9739 - val_loss: 0.1954

# %% [markdown]
# #### Using better architecture priors

# %% [markdown]
# #### Increasing model capacity

# %%
model = keras.Sequential([layers.Dense(10, activation="softmax")])
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_small_model = model.fit(
    train_images, train_labels, epochs=20, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8338 - loss: 0.6655 - val_accuracy: 0.9022 - val_loss: 0.3612
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.9028 - loss: 0.3533 - val_accuracy: 0.9145 - val_loss: 0.3096
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - accuracy: 0.9115 - loss: 0.3176 - val_accuracy: 0.9179 - val_loss: 0.2950
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - accuracy: 0.9154 - loss: 0.3019 - val_accuracy: 0.9215 - val_loss: 0.2829
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.9189 - loss: 0.2920 - val_accuracy: 0.9242 - val_loss: 0.2780
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.9199 - loss: 0.2852 - val_accuracy: 0.9252 - val_loss: 0.2738
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 273us/step - accuracy: 0.9222 - loss: 0.2805 - val_accuracy: 0.9259 - val_loss: 0.2722
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.9230 - loss: 0.2766 - val_accuracy: 0.9275 - val_loss: 0.2696
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - accuracy: 0.9239 - loss: 0.2734 - val_accuracy: 0.9268 - val_loss: 0.2711
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - accuracy: 0.9246 - loss: 0.2704 - val_accuracy: 0.9284 - val_loss: 0.2669
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.9253 - loss: 0.2685 - val_accuracy: 0.9277 - val_loss: 0.2666
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.9262 - loss: 0.2662 - val_accuracy: 0.9292 - val_loss: 0.2657
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.9273 - loss: 0.2645 - val_accuracy: 0.9283 - val_loss: 0.2656
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step - accuracy: 0.9275 - loss: 0.2626 - val_accuracy: 0.9273 - val_loss: 0.2667
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step - accuracy: 0.9279 - loss: 0.2614 - val_accuracy: 0.9288 - val_loss: 0.2637
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - accuracy: 0.9283 - loss: 0.2601 - val_accuracy: 0.9305 - val_loss: 0.2629
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 274us/step - accuracy: 0.9289 - loss: 0.2592 - val_accuracy: 0.9286 - val_loss: 0.2642
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - accuracy: 0.9296 - loss: 0.2579 - val_accuracy: 0.9300 - val_loss: 0.2620
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 265us/step - accuracy: 0.9295 - loss: 0.2571 - val_accuracy: 0.9285 - val_loss: 0.2645
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - accuracy: 0.9300 - loss: 0.2561 - val_accuracy: 0.9301 - val_loss: 0.2629

# %%
import matplotlib.pyplot as plt

val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with insufficient capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model = keras.Sequential(
    [
        layers.Dense(128, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9007 - loss: 0.3442 - val_accuracy: 0.9525 - val_loss: 0.1671
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9558 - loss: 0.1495 - val_accuracy: 0.9632 - val_loss: 0.1261
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.9685 - loss: 0.1031 - val_accuracy: 0.9672 - val_loss: 0.1135
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9761 - loss: 0.0781 - val_accuracy: 0.9717 - val_loss: 0.0946
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9816 - loss: 0.0609 - val_accuracy: 0.9686 - val_loss: 0.1101
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9848 - loss: 0.0493 - val_accuracy: 0.9737 - val_loss: 0.0878
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9880 - loss: 0.0393 - val_accuracy: 0.9726 - val_loss: 0.0952
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9900 - loss: 0.0316 - val_accuracy: 0.9697 - val_loss: 0.1076
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.9921 - loss: 0.0260 - val_accuracy: 0.9741 - val_loss: 0.0988
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9931 - loss: 0.0215 - val_accuracy: 0.9720 - val_loss: 0.1114
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9950 - loss: 0.0170 - val_accuracy: 0.9730 - val_loss: 0.1139
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9954 - loss: 0.0153 - val_accuracy: 0.9747 - val_loss: 0.1030
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9969 - loss: 0.0113 - val_accuracy: 0.9764 - val_loss: 0.1092
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9969 - loss: 0.0099 - val_accuracy: 0.9761 - val_loss: 0.1194
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9974 - loss: 0.0088 - val_accuracy: 0.9745 - val_loss: 0.1216
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9976 - loss: 0.0081 - val_accuracy: 0.9758 - val_loss: 0.1190
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.9771 - val_loss: 0.1224
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9984 - loss: 0.0057 - val_accuracy: 0.9768 - val_loss: 0.1226
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9748 - val_loss: 0.1285
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9765 - val_loss: 0.1316

# %%
plt.clf()
val_loss = history_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with appropriate capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model = keras.Sequential(
    [
        layers.Dense(600, activation="relu"),
        layers.Dense(600, activation="relu"),
        layers.Dense(600, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history_very_large_model = model.fit(
    train_images,
    train_labels,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9309 - loss: 0.2333 - val_accuracy: 0.9602 - val_loss: 0.1356
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9710 - loss: 0.1063 - val_accuracy: 0.9728 - val_loss: 0.1148
# Epoch 3/20
#   81/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9796 - loss: 0.0782
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 14
#       1 model = keras.Sequential(
#       2     [
#       3         layers.Dense(600, activation="relu"),
#    (...)      7     ]
#       8 )
#       9 model.compile(
#      10     optimizer="rmsprop",
#      11     loss="sparse_categorical_crossentropy",
#      12     metrics=["accuracy"],
#      13 )
# ---> 14 history_very_large_model = model.fit(
#      15     train_images,
#      16     train_labels,
#      17     epochs=20,
#      18     batch_size=32,
#      19     validation_split=0.2,
#      20 )
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/backend/jax/trainer.py:462, in JAXTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     453     state = self._get_jax_state(
#     454         trainable_variables=True,
#     455         non_trainable_variables=True,
#    (...)    458         purge_model_variables=True,
#     459     )
#     460     self._jax_state_synced = False
# --> 462 logs, state = self.train_function(state, iterator)
#     463 (
#     464     trainable_variables,
#     465     non_trainable_variables,
#     466     optimizer_variables,
#     467     metrics_variables,
#     468 ) = state
#     470 # Setting _jax_state enables callbacks to force a state
#     471 # sync if they need to.
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/backend/jax/trainer.py:257, in JAXTrainer._make_function.<locals>.iterator_step(state, iterator)
#     256 def iterator_step(state, iterator):
# --> 257     return step_function(state, next(iterator))
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/backend/jax/trainer.py:1050, in JAXEpochIterator._prefetch_numpy_iterator(self, numpy_iterator)
#    1048 while queue:
#    1049     yield queue.popleft()
# -> 1050     enqueue(1)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/backend/jax/trainer.py:1044, in JAXEpochIterator._prefetch_numpy_iterator.<locals>.enqueue(n)
#    1043 def enqueue(n=2):
# -> 1044     for data in itertools.islice(numpy_iterator, n):
#    1045         queue.append(_distribute_data(data))
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:344, in ArrayDataAdapter._get_iterator(self, slice_and_convert_fn, inputs)
#     339     indices = slice(start, stop)
#     341 slice_indices_and_convert_fn = functools.partial(
#     342     slice_and_convert_fn, indices=indices
#     343 )
# --> 344 yield tree.map_structure(
#     345     slice_indices_and_convert_fn, inputs, none_is_leaf=False
#     346 )
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/tree/tree_api.py:200, in map_structure(func, none_is_leaf, *structures)
#     167 @keras_export("keras.tree.map_structure")
#     168 def map_structure(func, *structures, none_is_leaf=True):
#     169     """Maps `func` through given structures.
#     170
#     171     Examples:
#    (...)    198             `assert_same_structure`.
#     199     """
# --> 200     return tree_impl.map_structure(func, *structures, none_is_leaf=none_is_leaf)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/tree/optree_impl.py:111, in map_structure(func, none_is_leaf, *structures)
#     107     return func(*args)
#     109 map_func = func_with_check if len(structures) > 1 else func
# --> 111 return optree.tree_map(
#     112     map_func, *structures, none_is_leaf=none_is_leaf, namespace="keras"
#     113 )
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/optree/ops.py:782, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     780 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     781 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 782 return treespec.unflatten(map(func, *flat_args))
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:253, in ArrayDataAdapter.get_jax_iterator.<locals>.slice_and_convert_to_jax(sliceable, indices)
#     251 def slice_and_convert_to_jax(sliceable, indices=None):
#     252     x = sliceable[indices]
# --> 253     x = sliceable.convert_to_jax_compatible(x)
#     254     return x
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_slicing.py:91, in Sliceable.convert_to_jax_compatible(cls, x)
#      79     """Convert a tensor to something compatible with `tf.data.Dataset`.
#      80
#      81     This can be a NumPy array, `tf.Tensor` or any other type of tensor that
#    (...)     87     Returns: converted version tensor.
#      88     """
#      89     return x
# ---> 91 @classmethod
#      92 def convert_to_jax_compatible(cls, x):
#      93     """Convert a tensor to something that the JAX backend can consume.
#      94
#      95     This can be a `JAX` array, `JAXSparse` or a NumPy array.
#    (...)    101     Returns: the converted tensor.
#     102     """
#     103     return x
#
# KeyboardInterrupt:

# %%
val_loss = history_very_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with too much capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Improving generalization

# %% [markdown]
# #### Dataset curation

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# #### Using early stopping

# %% [markdown]
# #### Regularizing your model

# %% [markdown]
# ##### Reducing the network's size

# %%
from keras.datasets import imdb

(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

train_data = vectorize_sequences(train_data)

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_original = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7740 - loss: 0.5419 - val_accuracy: 0.8584 - val_loss: 0.4169
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8885 - loss: 0.3456 - val_accuracy: 0.8804 - val_loss: 0.3275
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9138 - loss: 0.2621 - val_accuracy: 0.8861 - val_loss: 0.2996
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9299 - loss: 0.2106 - val_accuracy: 0.8902 - val_loss: 0.2791
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9427 - loss: 0.1770 - val_accuracy: 0.8904 - val_loss: 0.2739
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    smaller_model_val_loss,
    "b-",
    label="Validation loss of smaller model",
)
plt.title("Original model vs. smaller model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_larger_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7253 - loss: 0.5670 - val_accuracy: 0.8582 - val_loss: 0.3705
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.8680 - loss: 0.3270 - val_accuracy: 0.8769 - val_loss: 0.2987
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9113 - loss: 0.2296 - val_accuracy: 0.8209 - val_loss: 0.4418
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9283 - loss: 0.1782 - val_accuracy: 0.8791 - val_loss: 0.3024
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9473 - loss: 0.1465 - val_accuracy: 0.8775 - val_loss: 0.3128
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9670 - loss: 0.0936 - val_accuracy: 0.8422 - val_loss: 0.5077
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9651 - loss: 0.1018 - val_accuracy: 0.8836 - val_loss: 0.2922
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9949 - loss: 0.0298 - val_accuracy: 0.8829 - val_loss: 0.3929
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9791 - loss: 0.0894 - val_accuracy: 0.8852 - val_loss: 0.3683
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9991 - loss: 0.0092 - val_accuracy: 0.8824 - val_loss: 0.4641
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9826 - loss: 0.0779 - val_accuracy: 0.8825 - val_loss: 0.3895
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9999 - loss: 0.0058 - val_accuracy: 0.8849 - val_loss: 0.4820
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9999 - loss: 0.0024 - val_accuracy: 0.8856 - val_loss: 0.5444
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9821 - loss: 0.0900 - val_accuracy: 0.8812 - val_loss: 0.4519
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8826 - val_loss: 0.5215
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8822 - val_loss: 0.5886
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 1.0000 - loss: 6.7445e-04 - val_accuracy: 0.8837 - val_loss: 0.6331
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 1.0000 - loss: 4.4219e-04 - val_accuracy: 0.8826 - val_loss: 0.6583
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 1.0000 - loss: 3.0255e-04 - val_accuracy: 0.8814 - val_loss: 0.6880
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 1.0000 - loss: 2.3314e-04 - val_accuracy: 0.8809 - val_loss: 0.7027

# %%
plt.clf()
original_val_loss = history_original.history["val_loss"]
larger_model_val_loss = history_larger_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    larger_model_val_loss,
    "b-",
    label="Validation loss of larger model",
)
plt.title("Original model vs. larger model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Adding weight regularization

# %%
from keras.regularizers import l2

model = keras.Sequential(
    [
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_l2_reg = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7833 - loss: 0.6245 - val_accuracy: 0.8620 - val_loss: 0.4985
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8851 - loss: 0.4295 - val_accuracy: 0.8780 - val_loss: 0.4036
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9035 - loss: 0.3521 - val_accuracy: 0.8691 - val_loss: 0.3994
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9169 - loss: 0.3168 - val_accuracy: 0.8885 - val_loss: 0.3621
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9287 - loss: 0.2936 - val_accuracy: 0.8846 - val_loss: 0.3619
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9336 - loss: 0.2756 - val_accuracy: 0.8852 - val_loss: 0.3603
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9359 - loss: 0.2667 - val_accuracy: 0.8812 - val_loss: 0.3707
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9395 - loss: 0.2584 - val_accuracy: 0.8828 - val_loss: 0.3715
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9449 - loss: 0.2473 - val_accuracy: 0.8833 - val_loss: 0.3708
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9465 - loss: 0.2404 - val_accuracy: 0.8643 - val_loss: 0.4313
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9490 - loss: 0.2364 - val_accuracy: 0.8821 - val_loss: 0.3826
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.2349 - val_accuracy: 0.8809 - val_loss: 0.3853
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9521 - loss: 0.2286 - val_accuracy: 0.8719 - val_loss: 0.4204
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9522 - loss: 0.2280 - val_accuracy: 0.8754 - val_loss: 0.4016
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.2207 - val_accuracy: 0.8782 - val_loss: 0.3941
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9569 - loss: 0.2168 - val_accuracy: 0.8436 - val_loss: 0.5032
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9557 - loss: 0.2164 - val_accuracy: 0.8748 - val_loss: 0.4089
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9574 - loss: 0.2140 - val_accuracy: 0.8619 - val_loss: 0.4539
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.2124 - val_accuracy: 0.8754 - val_loss: 0.4193
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9603 - loss: 0.2066 - val_accuracy: 0.8679 - val_loss: 0.4416

# %%
plt.clf()
original_val_loss = history_original.history["val_loss"]
l2_val_loss = history_l2_reg.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    l2_val_loss,
    "b-",
    label="Validation loss of L2-regularized model",
)
plt.title(
    "Original model vs. L2-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from keras import regularizers

regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# ##### Adding dropout

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_dropout = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6399 - loss: 0.6334 - val_accuracy: 0.8492 - val_loss: 0.5192
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7594 - loss: 0.5187 - val_accuracy: 0.8683 - val_loss: 0.4264
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8095 - loss: 0.4432 - val_accuracy: 0.8740 - val_loss: 0.3580
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8447 - loss: 0.3848 - val_accuracy: 0.8864 - val_loss: 0.3104
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8688 - loss: 0.3447 - val_accuracy: 0.8878 - val_loss: 0.2888
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8856 - loss: 0.3016 - val_accuracy: 0.8905 - val_loss: 0.2789
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9004 - loss: 0.2700 - val_accuracy: 0.8905 - val_loss: 0.2764
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9072 - loss: 0.2456 - val_accuracy: 0.8909 - val_loss: 0.2830
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9221 - loss: 0.2208 - val_accuracy: 0.8838 - val_loss: 0.2927
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9277 - loss: 0.2013 - val_accuracy: 0.8902 - val_loss: 0.2916
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9351 - loss: 0.1836 - val_accuracy: 0.8900 - val_loss: 0.3140
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9407 - loss: 0.1652 - val_accuracy: 0.8876 - val_loss: 0.3466
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9473 - loss: 0.1509 - val_accuracy: 0.8876 - val_loss: 0.3380
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9471 - loss: 0.1482 - val_accuracy: 0.8871 - val_loss: 0.3589
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9521 - loss: 0.1327 - val_accuracy: 0.8845 - val_loss: 0.4057
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9536 - loss: 0.1285 - val_accuracy: 0.8863 - val_loss: 0.3991
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.1156 - val_accuracy: 0.8870 - val_loss: 0.4444
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9591 - loss: 0.1111 - val_accuracy: 0.8850 - val_loss: 0.4506
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9614 - loss: 0.1046 - val_accuracy: 0.8856 - val_loss: 0.4648
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.0994 - val_accuracy: 0.8864 - val_loss: 0.5086

# %%
plt.clf()
original_val_loss = history_original.history["val_loss"]
dropout_val_loss = history_dropout.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    dropout_val_loss,
    "b-",
    label="Validation loss of dropout-regularized model",
)
plt.title(
    "Original model vs. dropout-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
